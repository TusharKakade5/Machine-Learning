# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris = load_iris()

# %%
# Load data into a DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)
# Convert datatype to float
df = df.astype(float)
# append "target" and name it "label"
df['label'] = iris.target
# Use string label instead
df['label'] = df.label.replace(dict(enumerate(iris.target_names)))

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)   label
# 0                5.1               3.5  ...               0.2  setosa
# 1                4.9               3.0  ...               0.2  setosa
# 2                4.7               3.2  ...               0.2  setosa
# 3                4.6               3.1  ...               0.2  setosa
# 4                5.0               3.6  ...               0.2  setosa
#
# [5 rows x 5 columns]

# %%
# label -> one-hot encoding
label = pd.get_dummies(df['label'], prefix='label')
df = pd.concat([df, label], axis=1)
# drop old label
df.drop(['label'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  label_versicolor  label_virginica
# 0                5.1               3.5  ...                 0                0
# 1                4.9               3.0  ...                 0                0
# 2                4.7               3.2  ...                 0                0
# 3                4.6               3.1  ...                 0                0
# 4                5.0               3.6  ...                 0                0
#
# [5 rows x 7 columns]

# %%
# Creating X and y

X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]
# Convert DataFrame into np array
X = np.asarray(X)

y = df[['label_setosa', 'label_versicolor', 'label_virginica']]
# Convert DataFrame into np array
y = np.asarray(y)

# %%
# Split the data set in a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(
  X,
  y,
  test_size=0.20
)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120, 3)
# (30, 3)

# %% [markdown]
# Batch Normalization

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization

# %%
# Model without batch normalization
model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    Dense(128, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(3, activation='softmax')
]);

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                320
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 37,763
# Trainable params: 37,763
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model with batch normalization
model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(3, activation='softmax')
]);

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 64)                320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               8320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 39,555
# Trainable params: 38,659
# Non-trainable params: 896
# _________________________________________________________________

# %%
from tensorflow.keras.initializers import RandomNormal, Constant

# Model with a customized batch normalization
model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(
        momentum=0.95, 
        epsilon=0.005,
        beta_initializer=RandomNormal(mean=0.0, stddev=0.05), 
        gamma_initializer=Constant(value=0.9)
    ),
    Dense(3, activation='softmax')
]);

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 64)                320
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               8320
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# dense_17 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 39,555
# Trainable params: 38,659
# Non-trainable params: 896
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Epoch 1/200
# 3/3 - 2s - loss: 1.1993 - accuracy: 0.4778 - val_loss: 1.0631 - val_accuracy: 0.3667
# Epoch 2/200
# 3/3 - 0s - loss: 0.3399 - accuracy: 0.9111 - val_loss: 1.0534 - val_accuracy: 0.3667
# Epoch 3/200
# 3/3 - 0s - loss: 0.3246 - accuracy: 0.8889 - val_loss: 1.0521 - val_accuracy: 0.3667
# Epoch 4/200
# 3/3 - 0s - loss: 0.2126 - accuracy: 0.9444 - val_loss: 1.0458 - val_accuracy: 0.3667
# Epoch 5/200
# 3/3 - 0s - loss: 0.0764 - accuracy: 1.0000 - val_loss: 1.0404 - val_accuracy: 0.3667
# Epoch 6/200
# 3/3 - 0s - loss: 0.1399 - accuracy: 0.9667 - val_loss: 1.0354 - val_accuracy: 0.3667
# Epoch 7/200
# 3/3 - 0s - loss: 0.0713 - accuracy: 0.9889 - val_loss: 1.0252 - val_accuracy: 0.3667
# Epoch 8/200
# 3/3 - 0s - loss: 0.1174 - accuracy: 0.9667 - val_loss: 1.0270 - val_accuracy: 0.4333
# Epoch 9/200
# 3/3 - 0s - loss: 0.0860 - accuracy: 0.9778 - val_loss: 1.0326 - val_accuracy: 0.4667
# Epoch 10/200
# 3/3 - 0s - loss: 0.0728 - accuracy: 0.9778 - val_loss: 1.0357 - val_accuracy: 0.5000
# Epoch 11/200
# 3/3 - 0s - loss: 0.1022 - accuracy: 0.9667 - val_loss: 1.0309 - val_accuracy: 0.4667
# Epoch 12/200
# 3/3 - 0s - loss: 0.0671 - accuracy: 0.9778 - val_loss: 1.0242 - val_accuracy: 0.4667
# Epoch 13/200
# 3/3 - 0s - loss: 0.1662 - accuracy: 0.9667 - val_loss: 1.0198 - val_accuracy: 0.5000
# Epoch 14/200
# 3/3 - 0s - loss: 0.0831 - accuracy: 0.9667 - val_loss: 1.0145 - val_accuracy: 0.5000
# Epoch 15/200
# 3/3 - 0s - loss: 0.0475 - accuracy: 1.0000 - val_loss: 1.0090 - val_accuracy: 0.5333
# Epoch 16/200
# 3/3 - 0s - loss: 0.0652 - accuracy: 0.9778 - val_loss: 0.9984 - val_accuracy: 0.5333
# Epoch 17/200
# 3/3 - 0s - loss: 0.0512 - accuracy: 0.9778 - val_loss: 0.9715 - val_accuracy: 0.4667
# Epoch 18/200
# 3/3 - 0s - loss: 0.0426 - accuracy: 0.9889 - val_loss: 0.9629 - val_accuracy: 0.5000
# Epoch 19/200
# 3/3 - 0s - loss: 0.0576 - accuracy: 1.0000 - val_loss: 0.9513 - val_accuracy: 0.5000
# Epoch 20/200
# 3/3 - 0s - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.9599 - val_accuracy: 0.5000
# Epoch 21/200
# 3/3 - 0s - loss: 0.0379 - accuracy: 1.0000 - val_loss: 0.9704 - val_accuracy: 0.5000
# Epoch 22/200
# 3/3 - 0s - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.9783 - val_accuracy: 0.5000
# Epoch 23/200
# 3/3 - 0s - loss: 0.0340 - accuracy: 0.9889 - val_loss: 0.9932 - val_accuracy: 0.4667
# Epoch 24/200
# 3/3 - 0s - loss: 0.0616 - accuracy: 0.9889 - val_loss: 1.0130 - val_accuracy: 0.4667
# Epoch 25/200
# 3/3 - 0s - loss: 0.0215 - accuracy: 1.0000 - val_loss: 1.0249 - val_accuracy: 0.4667
# Epoch 26/200
# 3/3 - 0s - loss: 0.0190 - accuracy: 1.0000 - val_loss: 1.0357 - val_accuracy: 0.4667
# Epoch 27/200
# 3/3 - 0s - loss: 0.1124 - accuracy: 0.9556 - val_loss: 1.0473 - val_accuracy: 0.4667
# Epoch 28/200
# 3/3 - 0s - loss: 0.2058 - accuracy: 0.9556 - val_loss: 1.0594 - val_accuracy: 0.4667
# Epoch 29/200
# 3/3 - 0s - loss: 0.0546 - accuracy: 0.9778 - val_loss: 1.0951 - val_accuracy: 0.5000
# Epoch 30/200
# 3/3 - 0s - loss: 0.0336 - accuracy: 1.0000 - val_loss: 1.1536 - val_accuracy: 0.4000
# Epoch 31/200
# 3/3 - 0s - loss: 0.0547 - accuracy: 1.0000 - val_loss: 1.1682 - val_accuracy: 0.4000
# Epoch 32/200
# 3/3 - 0s - loss: 0.0439 - accuracy: 1.0000 - val_loss: 1.1811 - val_accuracy: 0.4000
# Epoch 33/200
# 3/3 - 0s - loss: 0.0315 - accuracy: 1.0000 - val_loss: 1.1671 - val_accuracy: 0.4667
# Epoch 34/200
# 3/3 - 0s - loss: 0.0864 - accuracy: 0.9667 - val_loss: 1.1297 - val_accuracy: 0.5000
# Epoch 35/200
# 3/3 - 0s - loss: 0.0283 - accuracy: 1.0000 - val_loss: 1.1143 - val_accuracy: 0.5333
# Epoch 36/200
# 3/3 - 0s - loss: 0.0239 - accuracy: 1.0000 - val_loss: 1.1071 - val_accuracy: 0.5000
# Epoch 37/200
# 3/3 - 0s - loss: 0.0206 - accuracy: 1.0000 - val_loss: 1.1012 - val_accuracy: 0.5333
# Epoch 38/200
# 3/3 - 0s - loss: 0.0255 - accuracy: 1.0000 - val_loss: 1.0891 - val_accuracy: 0.5333
# Epoch 39/200
# 3/3 - 0s - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9333
# Epoch 182/200
# 3/3 - 0s - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.1296 - val_accuracy: 0.9000
# Epoch 183/200
# 3/3 - 0s - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9000
# Epoch 184/200
# 3/3 - 0s - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.1663 - val_accuracy: 0.9000
# Epoch 185/200
# 3/3 - 0s - loss: 0.0251 - accuracy: 0.9889 - val_loss: 0.1919 - val_accuracy: 0.9000
# Epoch 186/200
# 3/3 - 0s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.2491 - val_accuracy: 0.8667
# Epoch 187/200
# 3/3 - 0s - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.2812 - val_accuracy: 0.8667
# Epoch 188/200
# 3/3 - 0s - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.2450 - val_accuracy: 0.8667
# Epoch 189/200
# 3/3 - 0s - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.8667
# Epoch 190/200
# 3/3 - 0s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.8667
# Epoch 191/200
# 3/3 - 0s - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.8667
# Epoch 192/200
# 3/3 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1144 - val_accuracy: 0.9000
# Epoch 193/200
# 3/3 - 0s - loss: 0.0933 - accuracy: 0.9778 - val_loss: 0.0944 - val_accuracy: 0.9667
# Epoch 194/200
# 3/3 - 0s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.0673 - val_accuracy: 0.9667
# Epoch 195/200
# 3/3 - 0s - loss: 0.0535 - accuracy: 0.9778 - val_loss: 0.0615 - val_accuracy: 0.9667
# Epoch 196/200
# 3/3 - 0s - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9667
# Epoch 197/200
# 3/3 - 0s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0638 - val_accuracy: 0.9667
# Epoch 198/200
# 3/3 - 0s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9667
# Epoch 199/200
# 3/3 - 0s - loss: 0.0768 - accuracy: 0.9667 - val_loss: 0.0845 - val_accuracy: 0.9333
# Epoch 200/200
# 3/3 - 0s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9333

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

# %%
plot_metric(history, 'accuracy')

# %%
plot_metric(history, 'loss')

# %%
# Evaluate the model on the test set
model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.1276 - accuracy: 0.9333
# [0.12758873403072357, 0.9333333373069763]
